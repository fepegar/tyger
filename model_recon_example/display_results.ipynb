# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt

# %%
model_recon = h5py.File('model_out.h5')
model_images = np.array(model_recon['dataset']['image_0']['data']).squeeze()

slice_of_interest = 1
plt.imshow(model_images[slice_of_interest,:,:])
