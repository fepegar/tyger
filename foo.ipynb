# %%
import h5py
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with h5py.File('/workspaces/tyger/x.h5') as f:
    # f['dataset']['image_0']['data']
    data = np.array(f['dataset']['image_0']['data']).squeeze()
    plt.imshow(data[(0,) * (len(data.shape) - 2) + (slice(None),)*2], cmap='gray')
